# %% [markdown]
# # Online Analyses

# %% [markdown]
#                              N={50,100}
#
# | p=0.25 => L=20                        |p=0.45 => L=40 |
# |---------------------------------------|-------------------|
# | Pred /CL(offline)                     | Pred /CL(offline) |
# | Pred /Online CL                       | Pred /Online CL  |
# | Anticipate Pred /Anticipate Online CL | Anticipate Pred /Anticipate Online CL  |
# | Online CL / Offline CL                | Online CL / Offline CL  |
# | Anticipate Online CL                  | Anticipate Online CL  |

# %% [markdown]
# # Table of Contents
#
# - [1. Geo Distribution param p =0.25](#param_025)
#     - [1.1 Quartile Tables](#025_q)
#         - [1.1.a Ratio Pred/Offline Clairvoyant with released date](#025_q_off)
#         - [1.1.b Ratio Pred/Online Clairvoyant with released date](#025_q_on)
#         - [1.1.c Ratio A_Pred/A_Online Clairvoyant with released date](#025_q_a_on)
#
#     - [1.2 Line Plots](#025_l)
#         - [1.2.a Ratio Pred/Offline Clairvoyant with released date](#025_l_off)
#         - [1.2.b Ratio Pred/Online Clairvoyant with released date](#025_l_on)
#         - [1.2.c Ratio A_Pred/A_Online Clairvoyant with released date](#025_l_a_on)
#
#     - [1.3 Histogramm](#025_h)
#         - [1.3.a Ratio Pred/Offline Clairvoyant with released date](#025_h_off)
#         - [1.3.b Ratio Pred/Online Clairvoyant with released date](#025_h_on)
#         - [1.3.c Ratio A_Pred/A_Online Clairvoyant with released date](#025_h_a_on)
#
#     - [1.4 Bars Graphs](#025_h)
#         - [1.4.a Ratio Pred/Offline Clairvoyant with released date](#025_b_off)
#         - [1.4.b Ratio Pred/Online Clairvoyant with released date](#025_b_on)
#         - [1.4.c Ratio A_Pred/A_Online Clairvoyant with released date](#025_b_a_on)
#
#     - [1.5 Online vs Offline : clairvoyant setting](#025_onVSoff)
#         - [1.5.a Ratio Online CL/Offline CL with released date](#025_onVoff_ocl)
#         - [1.5.b Ratio A_Online CL/Offline CL with released date](#025_onVoff_a_ocl)
#
# - [2. Geo Distribution param p =0.45](#param_045)
#     - [2.1 Quartile Tables](#045_q)
#         - [2.1.a Ratio Pred/Offline Clairvoyant with released date](#045_q_off)
#         - [2.1.b Ratio Pred/Online Clairvoyant with released date](#045_q_on)
#         - [2.1.c Ratio A_Pred/A_Online Clairvoyant with released date](#045_q_a_on)
#
#     - [2.2 Line Plots](#045_l)
#         - [2.2.a Ratio Pred/Offline Clairvoyant with released date](#045_l_off)
#         - [2.2.b Ratio Pred/Online Clairvoyant with released date](#045_l_on)
#         - [2.2.c Ratio A_Pred/A_Online Clairvoyant with released date](#045_l_a_on)
#
#     - [2.3 Histogramm](#045_h)
#         - [2.3.a Ratio Pred/Offline Clairvoyant with released date](#045_h_off)
#         - [2.3.b Ratio Pred/Online Clairvoyant with released date](#045_h_on)
#         - [2.3.c Ratio A_Pred/A_Online Clairvoyant with released date](#045_h_a_on)
#
#     - [2.4 Bars Graphs](#045_h)
#         - [2.4.a Ratio Pred/Offline Clairvoyant with released date](#045_b_off)
#         - [2.4.b Ratio Pred/Online Clairvoyant with released date](#045_b_on)
#         - [2.4.c Ratio A_Pred/A_Online Clairvoyant with released date](#045_b_a_on)
#
#     - [2.5 Online vs Offline : clairvoyant setting](#045_onVSoff)
#         - [2.5.a Ratio Online CL/Offline CL with released date](#045_onVoff_ocl)
#         - [2.5.b Ratio A_Online CL/Offline CL with released date](#045_onVoff_a_ocl)

# %%
import Functions

# %% [markdown]
# # Before getting the other results, we use [:1]

# %%
# Offline sincronia clairvoyant with released time CCT files
list_filename_025_cl = [
    "./Data/0.25/N50_L20/CL/results-0-100.txt",
    # "./Data/0.25/N100_L20/CL/results-0-100.txt",


    # "./Data/0.25/N50_L40/CL/results-0-100.txt",
    # "./Data/0.25/N100_L40/CL/results-0-100.txt",   
]

# Online sincronia clairvoyant with released time CCT files
list_filename_025_ocl = [
    "./Data/0.25/N50_L20/OCL/results-0-100.txt",
    # "./Data/0.25/N100_L20/OCL/results-0-100.txt",


    # "./Data/0.25/N50_L40/OCL/results-0-100.txt",
    # "./Data/0.25/N100_L40/OCL/results-0-100.txt",   
]

# Anticipate Online sincronia clairvoyant with released time CCT files
list_filename_025_a_ocl = [
    "./Data/0.25/N50_L20/OCL/A_results-0-100.txt",
    # "./Data/0.25/N100_L20/OCL/A_results-0-100.txt",


    # "./Data/0.25/N50_L40/OCL/A_results-0-100.txt",
    # "./Data/0.25/N100_L40/OCL/A_results-0-100.txt",   
]


# Online Pred CCT files
list_filename_025_Pred = [
    "./Data/0.25/N50_L20/Pred/results-0-100_cct_pred_n=1000.txt",
    # "./Data/0.25/N100_L20/Pred/results-0-100_cct_pred_n=1000.txt",


    # "./Data/0.25/N50_L40/Pred/results-0-100_cct_pred_n=1000.txt",
    # "./Data/0.25/N100_L40/Pred/results-0-100_cct_pred_n=1000.txt",
    
]

# Anticipate Online Pred CCT files
list_filename_025_a_Pred = [
    "./Data/0.25/N50_L20/Pred/A_results-0-100_cct_pred_n=1000.txt",
    # "./Data/0.25/N100_L20/Pred/A_results-0-100_cct_pred_n=1000.txt",


    # "./Data/0.25/N50_L40/Pred/A_results-0-100_cct_pred_n=1000.txt",
    # "./Data/0.25/N100_L40/Pred/A_results-0-100_cct_pred_n=1000.txt",
    
]

list_configuration_025 = [
    "L=20 n=50",
    # "L=20 n=100",


    # "L=40 n=50",
    # "L=40 n=100"
]

# %% [markdown]
# <a id="025_q"></a>
#
# ## 1.1 Quartile Tables

# %% [markdown]
# <a id="025_q_off"></a>
#
# ### 1.1.a Ratio Pred/Offline Clairvoyant with released date

# %%
print("\t--------------Pred(online)/CL_T(offline)------------")
for i in range(len(list_configuration_025[:1])):
    filename = list_filename_025_Pred[i]
    filename_compare = list_filename_025_cl[i]
    output_file = "/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/025_online_output_table_cl"+str(i+1)+".tex"

    Functions.quartiles_tables(filename, filename_compare =filename_compare,row=3,numero_inst= 0,title="Pred(online)/CL_T(offline), Conf:"+str(list_configuration_025[i]))#,output_file=output_file)
# Out:
# 	--------------Pred(online)/CL_T(offline)------------
# Quartiles Table for ratio of Pred(online)/CL_T(offline), Conf:L=20 n=50
#     Mean    Std     Q1     Q3
# 0  2.714  0.130  2.624  2.801
# 1  2.790  0.110  2.707  2.866
# 2  2.877  0.102  2.810  2.939
# 3  2.976  0.101  2.910  3.050
# 4  3.073  0.103  2.999  3.150
# 5  3.177  0.110  3.105  3.264
# 6  3.276  0.119  3.202  3.369
# 7  3.383  0.130  3.308  3.478
# 8  3.494  0.143  3.413  3.582
# 9  3.711  0.174  3.598  3.819

# %% [markdown]
# <a id="025_q_on"></a>
#
# ### 1.1.b Ratio Pred/Online Clairvoyant with released date

# %%
print("\t--------------Pred(online)/CL_T(online)------------")
for i in range(len(list_configuration_025[:1])):
    filename = list_filename_025_Pred[i]
    filename_compare = list_filename_025_ocl[i]
    output_file = "/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/025_online_output_table_ocl"+str(i+1)+".tex"

    Functions.quartiles_tables(filename, filename_compare =filename_compare,row=2,numero_inst= 0,title="Pred(online)/CL_T(offline), Conf:"+str(list_configuration_025[i]))#,output_file=output_file)
# Out:
# 	--------------Pred(online)/CL_T(online)------------
# Quartiles Table for ratio of Pred(online)/CL_T(offline), Conf:L=20 n=50
#     Mean    Std     Q1     Q3
# 0  1.000  0.000  1.000  1.000
# 1  1.029  0.036  1.006  1.053
# 2  1.061  0.039  1.032  1.086
# 3  1.098  0.043  1.069  1.125
# 4  1.134  0.048  1.105  1.163
# 5  1.172  0.055  1.141  1.204
# 6  1.209  0.062  1.175  1.248
# 7  1.249  0.068  1.210  1.295
# 8  1.290  0.076  1.246  1.339
# 9  1.370  0.091  1.312  1.430

# %% [markdown]
# <a id="025_q_a_on"></a>
#
# ### 1.1.c Ratio A_Pred/A_Online Clairvoyant with released date

# %%
print("\t--------------Pred(A_online)/CL_T(A_online)------------")
for i in range(len(list_configuration_025[:1])):
    filename = list_filename_025_a_Pred[i]
    filename_compare = list_filename_025_a_ocl[i]
    output_file = "/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/025_online_output_table_a_ocl"+str(i+1)+".tex"

    Functions.quartiles_tables(filename, filename_compare =filename_compare,row=2,numero_inst= 0,title="Pred(A_online)/CL_T(A_offline), Conf:"+str(list_configuration_025[i]))#,output_file=output_file)
# Out:
# 	--------------Pred(A_online)/CL_T(A_online)------------
# Quartiles Table for ratio of Pred(A_online)/CL_T(A_offline), Conf:L=20 n=50
#     Mean    Std     Q1     Q3
# 0  1.000  0.000  1.000  1.000
# 1  1.023  0.037  1.002  1.041
# 2  1.050  0.042  1.024  1.074
# 3  1.077  0.047  1.046  1.108
# 4  1.105  0.050  1.071  1.139
# 5  1.131  0.053  1.100  1.161
# 6  1.162  0.057  1.124  1.196
# 7  1.194  0.060  1.158  1.239
# 8  1.225  0.064  1.184  1.276
# 9  1.285  0.072  1.239  1.339

# %% [markdown]
# Combination of extracted quartiles

# %%
comb_files = [1,3]
f1 = "/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/025_online_output_table_a_ocl"+str(comb_files[0])+".tex"
f2 = "/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/025_online_output_table_a_ocl"+str(comb_files[1])+".tex"
output_f = "/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/025_online_output_table_combined_a_ocl"+str(comb_files[0])+"_"+str(comb_files[1])+".tex"
    
Functions.combination_2_files(f1, f2, output_f)

# %% [markdown]
# <a id="025_l"></a>
#
# ## 1.2 Line Plots

# %% [markdown]
# <a id="025_l_off"></a>
#
# ### 1.2.a Ratio Pred/Offline Clairvoyant with released date

# %%
output_file = "/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/025_online_line_plot_cl.png"
Functions.line_plot_all(list_filename=list_filename_025_Pred, list_filename_compare=list_filename_025_cl,list_configuration= list_configuration_025,row = 3,numero_inst= 36,all=0)#,output_file= output_file)#"/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/DRAFTS/Online-scheduling/Figures/online_line_plot_opt.png")#,ytitle=r'$\frac{SIN_{pred}}{OPT}$')

# numero_inst = {10,36,45,}
# Out:
# 1

# %%
print("All Instances")
output_file = "/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/025_online_line_plot_cl.png"
Functions.line_plot_all(list_filename=list_filename_025_Pred, list_filename_compare=list_filename_025_cl,list_configuration= list_configuration_025,row = 3,numero_inst= 0,all=0)#,output_file= output_file)#"/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/DRAFTS/Online-scheduling/Figures/online_line_plot_opt.png")#,ytitle=r'$\frac{SIN_{pred}}{OPT}$')
# Out:
# All Instances
# 1

# %% [markdown]
# <a id="025_l_on"></a>
#
# ### 1.2.b Ratio Pred/Online Clairvoyant with released date

# %%
output_file = "/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/025_online_line_plot_ocl.png"
Functions.line_plot_all(list_filename=list_filename_025_Pred, list_filename_compare=list_filename_025_ocl,list_configuration= list_configuration_025,row = 2,numero_inst= 36,all=0,y_bottom=0.80)#,output_file= output_file)#"/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/DRAFTS/Online-scheduling/Figures/online_line_plot_opt.png")#,ytitle=r'$\frac{SIN_{pred}}{OPT}$')

# numero_inst = {10,36,45,}
# Out:
# 1

# %% [markdown]
# <a id="025_l_a_on"></a>
#
# ### 1.2.c Ratio A_Pred/A_Online Clairvoyant with released date

# %%
output_file = "/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/025_online_line_plot_a_ocl.png"
Functions.line_plot_all(list_filename=list_filename_025_a_Pred, list_filename_compare=list_filename_025_a_ocl,list_configuration= list_configuration_025,row = 2,numero_inst= 36,all=0,y_bottom=0.8)#,output_file= output_file)#"/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/DRAFTS/Online-scheduling/Figures/online_line_plot_opt.png")#,ytitle=r'$\frac{SIN_{pred}}{OPT}$')

# numero_inst = {10,36,45,}
# Out:
# 1

# %% [markdown]
# <a id="025_h"></a>
#
# ## 1.3 Histogramm

# %% [markdown]
# <a id="025_h_off"></a>
#
# ### 1.3.a Ratio Pred/Offline Clairvoyant with released date

# %%
output_file="/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/025_online_cumul_cl"
Functions.histogramm_cumulation(list_filename_025_Pred, list_filename_025_cl,list_configuration_025,row = 3,numero_inst= 0,reduit=True,output_file=output_file)
# Out:
# Saved histogram to /home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/025_online_cumul_cl0.png

# %% [markdown]
# <a id="025_h_on"></a>
#
# ### 1.3.b Ratio Pred/Online Clairvoyant with released date

# %%
output_file="/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/025_online_cumul_ocl"
Functions.histogramm_cumulation(list_filename_025_Pred, list_filename_025_ocl,list_configuration_025,row = 2,numero_inst= 0,reduit=True,output_file=output_file)
# Out:
# Saved histogram to /home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/025_online_cumul_ocl0.png

# %% [markdown]
# <a id="025_h_a_on"></a>
#
# ### 1.3.c Ratio A_Pred/A_Online Clairvoyant with released date

# %%
output_file="/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/025_online_cumul_a_ocl"
Functions.histogramm_cumulation(list_filename_025_a_Pred, list_filename_025_a_ocl,list_configuration_025,row = 2,numero_inst= 0,reduit=True,output_file=output_file)
# Out:
# Saved histogram to /home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/025_online_cumul_a_ocl0.png

# %% [markdown]
# <a id="025_b"></a>
#
# ## 1.4 Bars Graphs

# %% [markdown]
# <a id="025_b_off"></a>
#
# ### 1.4.a Ratio Pred/Offline Clairvoyant with released date

# %%
output_file="/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/025_online_bars_cl.png"

Functions.bar_graph_pred(list_filename_025_Pred, list_filename_025_cl,list_configuration_025,row = 3,numero_inst= 0,y_slim=1.5) #,output_file= output_file)

# %% [markdown]
# <a id="025_b_on"></a>
#
# ### 1.4.b Ratio Pred/Online Clairvoyant with released date

# %%
output_file="/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/025_online_bars_ocl.png"

Functions.bar_graph_pred(list_filename_025_Pred, list_filename_025_ocl,list_configuration_025,row = 2,numero_inst= 0,y_slim=0.8) #,output_file= output_file)

# %% [markdown]
# <a id="025_b_a_on"></a>
#
# ### 1.4.c Ratio A_Pred/A_Online Clairvoyant with released date

# %%
output_file="/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/025_online_bars_a_ocl.png"

Functions.bar_graph_pred(list_filename_025_a_Pred, list_filename_025_a_ocl,list_configuration_025,row = 2,numero_inst= 0,y_slim=0.8) #,output_file= output_file)

# %% [markdown]
# <a id="025_onVSoff"></a>
#
# ## 1.5 Online vs Offline : clairvoyant setting

# %% [markdown]
# <a id="025_onVoff_ocl"></a>
#
# ### 1.5.a Ratio Online CL/Offline CL with released date

# %%
# output_file="/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/025_bar_graph_on_off_ocl.png"
Functions.bar_graph_extend(list_filename_on=list_filename_025_ocl, list_filename_off=list_filename_025_cl, list_configuration=list_configuration_025, numero_inst=0, y_slim=1.49) #, output_file=output_file)

# %% [markdown]
# <a id="025_onVoff_a_ocl"></a>
#
# ### 1.5.b Ratio A_Online CL/Offline CL with released date

# %%
# output_file="/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/025_bar_graph_on_off_a_cl.png"
Functions.bar_graph_extend(list_filename_on=list_filename_025_a_ocl, list_filename_off=list_filename_025_cl, list_configuration=list_configuration_025, numero_inst=0, y_slim=0.49) #, output_file=output_file)

# %% [markdown]
# <a id="param_045"></a>
#
# # 2. Geo Distribution param p = 0.45

# %%
# Offline sincronia clairvoyant with released time CCT files
list_filename_045_cl = [
    # "./Data/0.45/N50_L20/CL/results-0-100.txt",
    # "./Data/0.45/N100_L20/CL/results-0-100.txt",
    "./Data/0.45/N50_L40/CL/results-0-100.txt",
    "./Data/0.45/N100_L40/CL/results-0-100.txt",   
]

# Online sincronia clairvoyant with released time CCT files
list_filename_045_ocl = [
    # "./Data/0.45/N50_L20/OCL/results-0-100.txt",
    # "./Data/0.45/N100_L20/OCL/results-0-100.txt",
    "./Data/0.45/N50_L40/OCL/results-0-100.txt",
    "./Data/0.45/N100_L40/OCL/results-0-100.txt",   
]

# Anticipate Online sincronia clairvoyant with released time CCT files
list_filename_045_a_ocl = [
    # "./Data/0.45/N50_L20/OCL/A_results-0-100.txt",
    # "./Data/0.45/N100_L20/OCL/A_results-0-100.txt",
    "./Data/0.45/N50_L40/OCL/A_results-0-100.txt",
    "./Data/0.45/N100_L40/OCL/A_results-0-100.txt",   
]


# Online Pred CCT files
list_filename_045_Pred = [
    # "./Data/0.45/N50_L20/Pred/results-0-100_cct_pred_n=1000.txt",
    # "./Data/0.45/N100_L20/Pred/results-0-100_cct_pred_n=1000.txt",
    "./Data/0.45/N50_L40/Pred/results-0-100_cct_pred_n=1000.txt",
    "./Data/0.45/N100_L40/Pred/results-0-100_cct_pred_n=1000.txt",
    
]

# Anticipate Online Pred CCT files
list_filename_045_a_Pred = [
    # "./Data/0.45/N50_L20/Pred/A_results-0-100_cct_pred_n=1000.txt",
    # "./Data/0.45/N100_L20/Pred/A_results-0-100_cct_pred_n=1000.txt",
    "./Data/0.45/N50_L40/Pred/A_results-0-100_cct_pred_n=1000.txt",
    "./Data/0.45/N100_L40/Pred/A_results-0-100_cct_pred_n=1000.txt",
    
]

list_configuration_045 = [
    # "L=20 n=50",
    # "L=20 n=100",
    "L=40 n=50",
    "L=40 n=100"
]

# %% [markdown]
# <a id="045_q"></a>
#
# ## 2.1 Quartile Tables

# %% [markdown]
# <a id="045_q_off"></a>
#
# ## 2.1.a Ratio Pred/Offline Clairvoyant with released date

# %%
print("\t--------------Pred(online)/CL_T(offline)------------")
for i in range(len(list_configuration_045)):
    filename = list_filename_045_Pred[i]
    filename_compare = list_filename_045_cl[i]
    output_file = "/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/045_online_output_table_cl"+str(i+1)+".tex"

    Functions.quartiles_tables(filename, filename_compare =filename_compare,row=3,numero_inst= 0,title="Pred(online)/CL_T(offline), Conf:"+str(list_configuration_045[i]))#,output_file=output_file)

# %% [markdown]
# <a id="045_q_on"></a>
#
# ## 2.1.b Ratio Pred/Online Clairvoyant with released date

# %%
print("\t--------------Pred(online)/CL_T(online)------------")
for i in range(len(list_configuration_045)):
    filename = list_filename_045_Pred[i]
    filename_compare = list_filename_045_ocl[i]
    output_file = "/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/045_online_output_table_ocl"+str(i+1)+".tex"

    Functions.quartiles_tables(filename, filename_compare =filename_compare,row=2,numero_inst= 0,title="Pred(online)/CL_T(offline), Conf:"+str(list_configuration_045[i]))#,output_file=output_file)

# %% [markdown]
# <a id="045_q_a_on"></a>
#
# ## 2.1.c Ratio A_Pred/A_Online Clairvoyant with released date

# %%
print("\t--------------Pred(online)/CL_T(A_online)------------")
for i in range(len(list_configuration_045)):
    filename = list_filename_045_a_Pred[i]
    filename_compare = list_filename_045_a_ocl[i]
    output_file = "/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/045_online_output_table_a_ocl"+str(i+1)+".tex"

    Functions.quartiles_tables(filename, filename_compare =filename_compare,row=2,numero_inst= 0,title="Pred(online)/CL_T(A_online), Conf:"+str(list_configuration_045[i]))#,output_file=output_file)

# %% [markdown]
# Combination of extracted quartiles

# %%
comb_files = [1,3]
f1 = "/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/045_online_output_table_a_ocl"+str(comb_files[0])+".tex"
f2 = "/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/045_online_output_table_a_ocl"+str(comb_files[1])+".tex"
output_f = "/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/045_online_output_table_combined_a_ocl"+str(comb_files[0])+"_"+str(comb_files[1])+".tex"
    
Functions.combination_2_files(f1, f2, output_f)

# %% [markdown]
# <a id="045_l"></a>
#
# ## 2.2 Line Plots

# %% [markdown]
# <a id="045_l_off"></a>
#
# ## 2.2.a Ratio Pred/Offline Clairvoyant with released date

# %%
output_file = "/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/045_online_line_plot_cl.png"
Functions.line_plot_all(list_filename=list_filename_045_Pred, list_filename_compare=list_filename_045_cl,list_configuration= list_configuration_045,row = 3,numero_inst= 36,all=0)#,output_file= output_file)#"/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/DRAFTS/Online-scheduling/Figures/online_line_plot_opt.png")#,ytitle=r'$\frac{SIN_{pred}}{OPT}$')

# numero_inst = {10,36,45,}

# %% [markdown]
# <a id="045_l_on"></a>
#
# ## 2.2.b Ratio Pred/Online Clairvoyant with released date

# %%
output_file = "/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/045_online_line_plot_ocl.png"
Functions.line_plot_all(list_filename=list_filename_045_Pred, list_filename_compare=list_filename_045_ocl,list_configuration= list_configuration_045,row = 2,numero_inst= 36,all=0)#,output_file= output_file)#"/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/DRAFTS/Online-scheduling/Figures/online_line_plot_opt.png")#,ytitle=r'$\frac{SIN_{pred}}{OPT}$')

# numero_inst = {10,36,45,}

# %% [markdown]
# <a id="045_l_a_on"></a>
#
# ## 2.2.c Ratio A_Pred/A_Online Clairvoyant with released date

# %%
output_file = "/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/045_online_line_plot_a_ocl.png"
Functions.line_plot_all(list_filename=list_filename_045_a_Pred, list_filename_compare=list_filename_045_a_ocl,list_configuration= list_configuration_025,row = 3,numero_inst= 36,all=0)#,output_file= output_file)#"/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/DRAFTS/Online-scheduling/Figures/online_line_plot_opt.png")#,ytitle=r'$\frac{SIN_{pred}}{OPT}$')

# numero_inst = {10,36,45,}

# %% [markdown]
# <a id="045_h"></a>
#
# ## 2.3 Histogramm

# %% [markdown]
# <a id="045_h_off"></a>
#
# ## 2.3.a Ratio Pred/Offline Clairvoyant with released date

# %%
output_file="/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/045_online_cumul_cl"
Functions.histogramm_cumulation(list_filename_045_Pred, list_filename_045_cl,list_configuration_045,row = 3,numero_inst= 0,reduit=True,output_file=output_file)

# %% [markdown]
# <a id="045_h_on"></a>
#
# ## 2.3.b Ratio Pred/Online Clairvoyant with released date

# %%
output_file="/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/045_online_cumul_ocl"
Functions.histogramm_cumulation(list_filename_045_Pred, list_filename_045_ocl,list_configuration_045,row = 2,numero_inst= 0,reduit=True,output_file=output_file)

# %% [markdown]
# <a id="045_h_a_on"></a>
#
# ## 2.3.c Ratio A_Pred/A_Online Clairvoyant with released date

# %%
output_file="/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/045_online_cumul_a_ocl"
Functions.histogramm_cumulation(list_filename_045_a_Pred, list_filename_045_a_ocl,list_configuration_045,row = 2,numero_inst= 0,reduit=True,output_file=output_file)

# %% [markdown]
# <a id="045_b"></a>
#
# ## 2.4 Bars Graphs

# %% [markdown]
# <a id="045_b_off"></a>
#
# ## 2.4.a Ratio Pred/Offline Clairvoyant with released date

# %%
output_file="/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/045_online_bars_cl.png"

Functions.bar_graph_pred(list_filename_045_Pred, list_filename_045_cl,list_configuration_025,row = 3,numero_inst= 0,y_slim=1.5) #,output_file= output_file)

# %% [markdown]
# <a id="045_b_on"></a>
#
# ## 2.4.b Ratio Pred/Online Clairvoyant with released date

# %%
output_file="/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/045_online_bars_ocl.png"

Functions.bar_graph_pred(list_filename_045_Pred, list_filename_045_ocl,list_configuration_045,row = 2,numero_inst= 0,y_slim=1.5) #,output_file= output_file)

# %% [markdown]
# <a id="045_b_a_on"></a>
#
# ## 2.4.c Ratio A_Pred/A_Online Clairvoyant with released date

# %%
output_file="/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/045_online_bars_a_ocl.png"

Functions.bar_graph_pred(list_filename_045_a_Pred, list_filename_045_a_ocl,list_configuration_045,row = 2,numero_inst= 0,y_slim=1.5) #,output_file= output_file)

# %% [markdown]
# <a id="045_onVSoff"></a>
#
# ## 2.5 Online vs Offline : clairvoyant setting

# %% [markdown]
# <a id="045_onVoff_ocl"></a>
#
# ### 2.5.a Ratio Online CL/Offline CL with released date

# %%
# output_file="/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/045_bar_graph_on_off_ocl.png"
Functions.bar_graph_extend(list_filename_on=list_filename_045_ocl, list_filename_off=list_filename_045_cl, list_configuration=list_configuration_025, numero_inst=0, y_slim=1.49) #, output_file=output_file)

# %% [markdown]
# <a id="045_onVoff_a_ocl"></a>
#
# ### 2.5.b Ratio A_Online CL/Offline CL with released date

# %%
# output_file="/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/SUBMISSIONS/ToN2025_to_overleaf/Figures/New_Figs/045_bar_graph_on_off_a_cl.png"
Functions.bar_graph_extend(list_filename_on=list_filename_045_a_ocl, list_filename_off=list_filename_045_cl, list_configuration=list_configuration_045, numero_inst=0, y_slim=1.49) #, output_file=output_file)

# %% [markdown]
# <a id="ma-cible"></a>
#
# ### Mon titre de section

# %% [markdown]
# ## Quartiles

# %%
# Offline sincronia clairvoyant with released time CCT files
list_filename_cl = [
    "./Data/0.25/N50_L20/CL/results-0-50.txt",
    "./Data/0.45/N100_L40/CL/results-0-50.txt"
    
]

# Online sincronia clairvoyant with released time CCT files
list_filename_ocl = [
    "./Data/0.25/N50_L20/OCL/results-0-50.txt",
    "./Data/0.45/N100_L40/OCL/results-0-50.txt"
    
]

# Online sincronia clairvoyant with released time CCT files SP Update
list_filename_ocl_SP_Update = [
    "./Data/0.25/N50_L20/OCL/SpUpdate_results-0-50.txt",
    "./Data/0.45/N100_L40/OCL/SpUpdate_results-0-50.txt"
    
]


# Online Pred CCT files
list_filename_pred = [
    "./Data/0.25/N50_L20/Pred/results-0-50_cct_pred_n=1000.txt",
    "./Data/0.45/N100_L40/Pred/results-0-50_cct_pred_n=1000.txt" 
]

# Online Pred CCT files
list_filename_pred_SP_Update = [
    "./Data/0.25/N50_L20/Pred/SpUpdate_results-0-50_cct_pred_n=1000.txt",
    "./Data/0.45/N100_L40/Pred/SpUpdate_results-0-50_cct_pred_n=1000.txt" 
]

list_configuration_025 = [
    "L=20 n=50",
    "L=40 n=100"
]

# %%
# Processing
p=0.25
folder_path = "/home/asangho/Desktop/These/Coflow/Coflow_Scheduling/Code/Code_online/Outputs/paper/0.25/N50_L20/Pred"

output_file = "/home/asangho/Desktop/These/Coflow/Coflow_Scheduling/Code/Plots/Numerical/Online/Data/0.25/N50_L20/Pred/results-0-50_cct_pred_n=1000.txt"
Functions.concatenation_pred_files(folder_path,output_file, prefix="results")


output_file_SP_update = "/home/asangho/Desktop/These/Coflow/Coflow_Scheduling/Code/Plots/Numerical/Online/Data/0.25/N50_L20/Pred/SpUpdate_results-0-50_cct_pred_n=1000.txt"
Functions.concatenation_pred_files(folder_path,output_file=output_file_SP_update, prefix="SpUpdate_results")

# %%
# p=0.45
folder_path = "/home/asangho/Desktop/These/Coflow/Coflow_Scheduling/Code/Code_online/Outputs/paper/0.45/N100_L40/Pred"

output_file = "/home/asangho/Desktop/These/Coflow/Coflow_Scheduling/Code/Plots/Numerical/Online/Data/0.45/N100_L40/Pred/results-0-50_cct_pred_n=1000.txt"
Functions.concatenation_pred_files(folder_path,output_file, prefix="results")


output_file_SP_update = "/home/asangho/Desktop/These/Coflow/Coflow_Scheduling/Code/Plots/Numerical/Online/Data/0.45/N100_L40/Pred/SpUpdate_results-0-50_cct_pred_n=1000.txt"
Functions.concatenation_pred_files(folder_path,output_file=output_file_SP_update, prefix="SpUpdate_results")

# %% [markdown]
# Quartiles

# %%
Functions.quartiles_tables(filename= list_filename_pred[0], filename_compare =list_filename_cl[0],row=3,numero_inst= 0,title="Pred(online)/CL(offline), Conf:"+str(list_configuration[0]))#,output_file=output_file)


Functions.quartiles_tables(filename= list_filename_pred_SP_Update[0], filename_compare =list_filename_cl[0],row=3,numero_inst= 0,title="SP_UpdatePred(online)/CL(offline), Conf:"+str(list_configuration[0]))#,output_file=output_file)
# Out:
# Quartiles Table for ratio of Pred(online)/CL(offline), Conf:L=20 n=50
#     Mean    Std     Q1     Q3
# 0  2.694  0.125  2.604  2.778
# 1  2.970  0.148  2.870  3.076
# 2  3.173  0.144  3.067  3.276
# 3  3.370  0.156  3.264  3.477
# 4  3.697  0.190  3.594  3.848
# Quartiles Table for ratio of SP_UpdatePred(online)/CL(offline), Conf:L=20 n=50
#     Mean    Std     Q1     Q3
# 0  1.017  0.046  0.985  1.039
# 1  1.085  0.047  1.055  1.108
# 2  1.151  0.057  1.106  1.189
# 3  1.212  0.076  1.167  1.233
# 4  1.321  0.093  1.243  1.393

# %%
Functions.quartiles_tables(filename= list_filename_pred[0], filename_compare =list_filename_ocl[0],row=2,numero_inst= 0,title="Pred(online)/CL(online), Conf:"+str(list_configuration_025[0]))#,output_file=output_file)

Functions.quartiles_tables(filename= list_filename_pred_SP_Update[0], filename_compare =list_filename_ocl_SP_Update[0],row=2,numero_inst= 0,title="SP_UpdatePred(online)/CL(online), Conf:"+str(list_configuration_025[0]))#,output_file=output_file)
# Out:
# Quartiles Table for ratio of Pred(online)/CL(online), Conf:L=20 n=50
#     Mean    Std     Q1     Q3
# 0  1.000  0.000  1.000  1.000
# 1  1.103  0.047  1.066  1.135
# 2  1.179  0.061  1.134  1.216
# 3  1.253  0.078  1.205  1.313
# 4  1.375  0.091  1.312  1.442
# Quartiles Table for ratio of SP_UpdatePred(online)/CL(online), Conf:L=20 n=50
#     Mean    Std     Q1     Q3
# 0  1.000  0.000  1.000  1.000
# 1  1.068  0.047  1.033  1.095
# 2  1.133  0.058  1.093  1.174
# 3  1.193  0.068  1.153  1.225
# 4  1.300  0.090  1.233  1.361

# %% [markdown]
# Line Plots

# %%
print("Line PLots for ratio of Pred(online)/CL(offline)")
Functions.line_plot_all(list_filename=list_filename_pred, list_filename_compare=list_filename_cl,list_configuration= list_configuration_025,row = 3,numero_inst= 0,all=0,ytitle=r'$\frac{C^{pred}}{C^{CL}}$')#,output_file= output_file)#"/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/DRAFTS/Online-scheduling/Figures/online_line_plot_opt.png")#,ytitle=r'$\frac{SIN_{pred}}{OPT}$')
# Out:
# Line PLots for ratio of Pred(online)/CL(offline)
# 1

# %%
print("Line PLots for ratio of SP_Update_Pred(online)/CL(offline)")
Functions.line_plot_all(list_filename=list_filename_pred_SP_Update, list_filename_compare=list_filename_cl,list_configuration= list_configuration_025,row = 3,numero_inst= 0,all=0,ytitle=r'$\frac{C^{pred}}{C^{CL}}$',y_bottom=0.5)#,output_file= output_file)#"/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/DRAFTS/Online-scheduling/Figures/online_line_plot_opt.png")#,ytitle=r'$\frac{SIN_{pred}}{OPT}$')
# Out:
# Line PLots for ratio of SP_Update_Pred(online)/CL(offline)
# 1

# %%
print("Line PLots for ratio of Pred(online)/CL(online)")
Functions.line_plot_all(list_filename=list_filename_pred, list_filename_compare=list_filename_ocl,list_configuration= list_configuration_025,row = 2,numero_inst= 0,all=0,ytitle=r'$\frac{C^{pred}}{C^{CL}}$',y_bottom=0.5)#,output_file= output_file)#"/home/asangho/Desktop/Workspace/THESE_AMINATA_SANGHO/DRAFTS/Online-scheduling/Figures/online_line_plot_opt.png")#,ytitle=r'$\frac{SIN_{pred}}{OPT}$')
# Out:
# Line PLots for ratio of Pred(online)/CL(online)
# 1
